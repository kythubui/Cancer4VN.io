# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers.generation import GenerationConfig

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2-0.5B", trust_remote_code=True)

model = AutoModelForCausalLM.from_pretrained(
    "Qwen/Qwen2-0.5B",
    device_map="auto",
    trust_remote_code=True
).eval()

response, history = model.chat(tokenizer, "What is cancer?", history=None)
print(response)
# Out:
# 2025-10-02 20:16:40.361927: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-02 20:16:40.361947: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-02 20:16:40.362665: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-02 20:16:40.366388: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-02 20:16:40.883070: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#       4 tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2-0.5B", trust_remote_code=True)
#       6 model = AutoModelForCausalLM.from_pretrained(
#       7     "Qwen/Qwen2-0.5B",
#       8     device_map="auto",
#       9     trust_remote_code=True
#      10 ).eval()
# ---> 12 response, history = model.chat(tokenizer, "What is cancer?", history=None)
#      13 print(response)
#
# File ~/anaconda3/envs/qwen32b/lib/python3.10/site-packages/torch/nn/modules/module.py:1962, in Module.__getattr__(self, name)
#    1960     if name in modules:
#    1961         return modules[name]
# -> 1962 raise AttributeError(
#    1963     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1964 )
#
# AttributeError: 'Qwen2ForCausalLM' object has no attribute 'chat'
